# %%
# Discover Dataflows

# %%
# import pandas as pd

# %%
import sdmx

bis = sdmx.Client("BIS")

flows = bis.dataflow()

# %%
for k in list(flows.dataflow.keys())[:20]:
    print(k)

# %%
for k in list(flows.dataflow.keys())[:20]:
    print(k)
